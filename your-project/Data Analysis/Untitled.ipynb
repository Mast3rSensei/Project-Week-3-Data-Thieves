# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('zomato_restaurants_lisbon', index_col='ID')
df
# Out:
#                                                     name     neighborhood  \
# ID
# 0                                       Geladaria Freddo         Corroios
# 1                                       Restaurante Baía   Cascais Centro
# 2                                               Menos Um         Venteira
# 3                                              Real Cake    Loures Centro
# 4                                         Bolos Caseiros  Penha de França
# ...                                                  ...              ...
# 12672  Inevitável - Vila Galé Collection Palácio dos ...    Paço de Arcos
# 12673               Flor de Lis - EPIC SANA Lisboa Hotel             Rato
# 12674                        Midori - Penha Longa Resort      Alcabideche
# 12675                                             Tágide           Chiado
# 12676              A Confraria - York House Lisboa Hotel           Santos
#
#       avg_rating #_of_ratings                        avg_cost  \
# ID
# ...

# %%
df[df['cash_cards?'] == "How do we calculate cost for two?"]
# Out:
#                      name   neighborhood avg_rating #_of_ratings  \
# ID
# 1318            Rosa Café  Linda-a-Velha          -            0
# 2443         Café da Mila       São João        3.0            2
# 3719  Cafetaria da Parada       São João        3.2            0
#
#                           avg_cost                        cash_cards?  \
# ID
# 1318  6 € for two people (approx.)  How do we calculate cost for two?
# 2443  8 € for two people (approx.)  How do we calculate cost for two?
# 3719  6 € for two people (approx.)  How do we calculate cost for two?
#
#                type                                   cuisine  \
# ID
# 1318  ['Snack Bar']  ['Cafe', 'Finger Food', 'Linda-a-Velha']
# 2443  ['Snack Bar']       ['Cafe', 'Finger Food', 'São João']
# 3719  ['Snack Bar']            ['Cafe', 'Bakery', 'São João']
#
#                                              more_infos
# ID
# 1318  ['Breakfast', 'Takeaway Available', 'Full Bar ...
# ...
